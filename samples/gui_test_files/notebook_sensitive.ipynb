# %% [markdown]
# # 고객 결제 장애 분석
# production 환경의 customer_payment 테이블 장애 원인을 분석합니다.

# %%
API_KEY = 'AKIAIOSFODNN7EXAMPLE'
BASE_URL = 'https://internal-gateway.company.internal/api/v2'
print('debug')
# Out:
# password=output-should-be-stripped
